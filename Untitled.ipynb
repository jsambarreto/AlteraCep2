# %%
import alteracep2 as cep

cep.executarABagaca('producao','PDF/')
# Out:
# CarlosMarinho.pdf
# Page No - 1
# MINISTÉRIO DA EDUCAÇÃO
# INSTITUTO NACIONAL DE ESTUDOS E PESQUISAS EDUCACIONAIS ANÍSIO TEIXEIRA
# DIRETORIA DE ESTATÍSTICAS EDUCACIONAIS
# RELATÓRIO DOS ERROS IDENTIFICADOS NA VALIDAÇÃO DO ARQUIVO DE MIGRAÇÃO - COLETA 2022
# Fonte
# Inep/MEC - Migra Dados - OnLine - Tipo: MC
# Data de envio
# 12/07/2022 16:36:03
# Arquivo verificado
# CARLOS_MARINHO_7.txt (566532)
# Tamanho do arquivo
# 52406 bytes
# Data de geração do relatório
# 13/07/2022 07:52:51
# Versão do Migração
# 7.4.849
# Versão do Negócio
# 2.4.886
# Nº
# Entidade
# Reg./Reg.
# Linha
# Campo
# Conteúdo
# Id. na escola
# Mensagem
# 1
# 29468426
# 30/6
# 38
# "5 - Número do
# CPF"
# 11409253503
# 202200994
# "Pessoa física não importada. O campo "Número do CPF" foi
# preenchido com CPF igual a outra pessoa física."
# 2
# 29468426
# 30/7
# 38
# "6 - Nome
# completo"
# AYSCHA KAROLAINE DO MONTE -- AYSCHA
# KAROLAINE DO MONTE SILVA
# 202200994
# ...

# %%
import tabula
import pandas as pd

# Read pdf into list of DataFrame
#dfs = tabula.read_pdf("C:\\Users\\jsamb\\Desenvolvimento\\python\\AlteraCep2\\PDF\\CarlosMarinho.pdf", pages='all')

# convert PDF into CSV file
tabula.convert_into("PDF/CarlosMarinho.pdf", "output.csv", output_format="csv", pages='all')
dfs = pd.read_csv('output.csv', sep=',', encoding='latin1')
dfs
# Out:
#       No    Entidade Reg./Reg.  Linha                      Campo  \
# 0    NaN         NaN       NaN    NaN             "5 - Número do
# 1    1.0  29468426.0      30/6   38.0                        NaN
# 2    NaN         NaN       NaN    NaN                       CPF"
# 3    NaN         NaN       NaN    NaN                  "6 - Nome
# 4    2.0  29468426.0      30/7   38.0                        NaN
# 5    NaN         NaN       NaN    NaN                  completo"
# 6    3.0  29468426.0      30/2   56.0                 "41 - CEP"
# 7    4.0  29468426.0      30/2   57.0                 "41 - CEP"
# 8    5.0  29468426.0      30/2   58.0                 "41 - CEP"
# 9    6.0  29468426.0      30/2   59.0                 "41 - CEP"
# 10   7.0  29468426.0      30/2   60.0                 "41 - CEP"
# 11   8.0  29468426.0      30/2   69.0                 "41 - CEP"
# 12   9.0  29468426.0      30/2   70.0                 "41 - CEP"
# ...
